# %%
from training import make_predictions 
from data0.dataset import uarray
from data0.run_functions import make_predictions_metadata_dict
from data0.config import get_config
# from .model import load_model

config_path = '../../../HPC_runs/input_refac0/model_config.json'
config_dict = get_config(config_path)

this_pred_metadata = make_predictions_metadata_dict(
    '../../../HPC_runs/input_refac0',
    config_path,
    config_dict,
    version=1,
    model_fmt='keras',
)
this_pred_metadata 
# uarr = uarray('../../../inputfiles/no2_2005_2020_old/no2_2005_2020_old.nc', is_input_set=True)
# 
# unet = load_model('../../../HPC_runs/input_refac0/unet_stage1_model.keras')

# make_predictions(
# )
# Out:
# {'savedir': '../../../HPC_runs/input_refac0',
#  'config_path': '../../../HPC_runs/input_refac0/model_config.json',
#  'config_dict': {'input_set': 'no2_2005_2020',
#   'x_vars': ['no2',
#    'no2_tm1',
#    'u10',
#    'v10',
#    'blh',
#    'sp',
#    'skt',
#    't2m',
#    'ssrd'],
#   'model_scale_factors': {'nox': 1000000000000.0,
#    'no2': 0.001,
#    'no2_tm1': 0.001,
#    'u10': 1,
#    'v10': 1,
#    'blh': 0.001,
#    'sp': 1e-05,
#    'skt': 1,
#    't2m': 1,
#    'ssrd': 1e-06},
#   'zfi_vars': [],
#   'lsm_vars': [],
#   'stage_2': True,
#   'stage_2_cutoff': 2013,
#   'n_epochs': 100,
#   'split_year': 2019,
#   'split_value': 0.9,
#   'grid_size': [56, 120],
#   'act_reg': 'L1',
#   'act_reg_factor': 1e-08},
#  'version': 1,
#  'model_fmt': 'keras',
#  'train_years': {'stage1': [], 'stage2': []},
#  'pred_years': {'stage1': [], 'stage2': []}}
